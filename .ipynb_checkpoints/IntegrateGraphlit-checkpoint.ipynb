# %% [markdown]
# # Notes on Graphlit
# https://docs.graphlit.dev/graphlit-data-api/quickstart/ingest-content/ingest-web-page

# %%
# https://github.com/graphlit/graphlit-client-python
# https://docs.graphlit.dev/graphlit-data-api/api-reference/feeds/create-web-feed

# %% [markdown]
# ![image.png](attachment:7db73e49-f6de-4ad5-8b9d-a535a5d45329.png)
# ![image.png](attachment:e09e2f75-b20e-4087-8367-11801ca6dcdb.png)
#
# For some reason, you can't use www for the url it has to be https
